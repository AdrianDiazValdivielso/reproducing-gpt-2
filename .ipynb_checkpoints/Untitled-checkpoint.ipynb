# %%
from transformers import GPT2LMHeadModel

# %%
model_hf = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model_hf = GPT2LMHeadModel.from_pretrained("gpt2")
#
# File ~\Projects\reproducing-gpt-2\.venv\Lib\site-packages\transformers\utils\import_utils.py:2157, in DummyObject.__getattribute__(cls, key)
#    2155 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2156     return super().__getattribute__(key)
# -> 2157 requires_backends(cls, cls._backends)
#
# File ~\Projects\reproducing-gpt-2\.venv\Lib\site-packages\transformers\utils\import_utils.py:2143, in requires_backends(obj, backends)
#    2140         failed.append(msg.format(name))
#    2142 if failed:
# -> 2143     raise ImportError("".join(failed))
#
# ImportError:
# GPT2LMHeadModel requires the PyTorch library but it was not found in your environment. Check out the instructions on the
# ...
